# %%
from weather_fetch import write_query_config, fetch_and_save
from preprocess_311 import preprocess_311

# %%
outs = preprocess_311('../All_Service_Requests_-_2023.csv')
# Out:
# Reading ../All_Service_Requests_-_2023.csv  (year=2023) …
#   Pothole rows: 2,891  across wards: ['Null', 'Ward 1', 'Ward 2', 'Ward 3', 'Ward 4', 'Ward 5', 'Ward 6', 'Ward 7', 'Ward 8']
#   Wrote data/null_potholes_2023.parquet  (67 rows)
#   Wrote data/ward1_potholes_2023.parquet  (220 rows)
#   Wrote data/ward2_potholes_2023.parquet  (382 rows)
#   Wrote data/ward3_potholes_2023.parquet  (527 rows)
#   Wrote data/ward4_potholes_2023.parquet  (411 rows)
#   Wrote data/ward5_potholes_2023.parquet  (409 rows)
#   Wrote data/ward6_potholes_2023.parquet  (340 rows)
#   Wrote data/ward7_potholes_2023.parquet  (255 rows)
#   Wrote data/ward8_potholes_2023.parquet  (280 rows)

# %%
# get lat, lon data from 311
import pandas as pd
df = pd.read_csv('../All_Service_Requests_-_2023.csv')

# %%
lat, lon = df[df['WARD'] == 'Ward 3']['LATITUDE'].mean(), df[df['WARD'] == 'Ward 3']['LONGITUDE'].mean()

# %%
# write a query config
query_config = write_query_config('Ward 3', lat, lon, '2022-12-01', '2023-12-31')
# Out:
# Config written → configs/weather_ward3_20221201_20231231.json

# %%
query_config
# Out:
# 'configs/weather_ward3_20221201_20231231.json'

# %%
# fetch and save
df_hourly, metadata = fetch_and_save(query_config)
# Out:
# Fetching from Open-Meteo API for Ward 3 …
#   Coordinates : (38.939126092220974, -77.077979511738)
#   Date range  : 2022-12-01 → 2023-12-31
# Saved  data/weather_cache/weather_ward3_20221201_20231231.parquet  (9,504 rows)
# Saved  data/weather_cache/weather_ward3_20221201_20231231_metadata.json
