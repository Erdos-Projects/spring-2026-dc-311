# %%
from modeling.evaluate import _load_run
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from omegaconf import DictConfig, OmegaConf

# %%
# load the experimental config 
cfg = OmegaConf.load("../results/run_ward3_negbin_glm_20221201_20231231_20260316_d6f70f15.yaml")

# %%
model_path = _load_run(cfg)
# with open(model_path, "rb") as f:
#     saved = pickle.load(f)
# model = saved["model"]
# feature_cols = saved["feature_cols"]
# feat_params = SimpleNamespace(**saved["feat_params"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model_path = _load_run(cfg)
#       2 # with open(model_path, "rb") as f:
#       3 #     saved = pickle.load(f)
#       4 # model = saved["model"]
#       5 # feature_cols = saved["feature_cols"]
#       6 # feat_params = SimpleNamespace(**saved["feat_params"])
#
# File ~/Documents/ErdosSpring26/spring-2026-dc-311/modeling/evaluate.py:43, in _load_run(cfg)
#      41 run_id = cfg.get("load_model", None)
#      42 if not run_id:
# ---> 43     raise ValueError(
#      44         "cfg.load_model is not set. "
#      45         "Pass load_model=<run_id> printed at train time, e.g.:\n"
#      46         "  python -m modeling.evaluate load_model=20260316_0c29fda0"
#      47     )
#      49 matches = list(Path("results").glob(f"run_{cfg.ward.name}_*_{run_id}.yaml"))
#      50 if not matches:
#
# ValueError: cfg.load_model is not set. Pass load_model=<run_id> printed at train time, e.g.:
#   python -m modeling.evaluate load_model=20260316_0c29fda0

# %%
type(cfg)
# Out:
# omegaconf.dictconfig.DictConfig
